# %% [markdown]
# # 用查询功能做出结论

# %%
import pandas as pd

# %%
# 加载 `winequality_edited.csv`

df =pd.read_csv('winequality_edited_addcut.csv')

# %% [markdown]
# ### 酒精含量高的酒是否评分较高？

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 14 columns):
# fixed acidity           6497 non-null float64
# volatile acidity        6497 non-null float64
# citric acid             6497 non-null float64
# residual sugar          6497 non-null float64
# chlorides               6497 non-null float64
# free sulfur dioxide     6497 non-null float64
# total sulfur dioxide    6497 non-null float64
# density                 6497 non-null float64
# pH                      6497 non-null float64
# sulphates               6497 non-null float64
# alcohol                 6497 non-null float64
# quality                 6497 non-null int64
# color                   6497 non-null object
# acidity_levels          6496 non-null object
# dtypes: float64(11), int64(1), object(2)
# memory usage: 710.7+ KB

# %%
# 获取酒精含量的中位数
# 中位数为 10.30
df['alcohol'].describe()
# Out:
# count    6497.000000
# mean       10.491801
# std         1.192712
# min         8.000000
# 25%         9.500000
# 50%        10.300000
# 75%        11.300000
# max        14.900000
# Name: alcohol, dtype: float64

# %%
# 选择酒精含量小于中位数的样本
low_alcohol =df.query('alcohol < 10.30')
low_alcohol
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00            1.90      0.076
# 1               7.8             0.880         0.00            2.60      0.098
# 2               7.8             0.760         0.04            2.30      0.092
# 3              11.2             0.280         0.56            1.90      0.075
# 4               7.4             0.700         0.00            1.90      0.076
# 5               7.4             0.660         0.00            1.80      0.075
# 6               7.9             0.600         0.06            1.60      0.069
# 7               7.3             0.650         0.00            1.20      0.065
# 8               7.8             0.580         0.02            2.00      0.073
# 10              6.7             0.580         0.08            1.80      0.097
# 12              5.6             0.615         0.00            1.60      0.089
# 13              7.8             0.610         0.29            1.60      0.114
# 14              8.9             0.620         0.18            3.80      0.176
# 15              8.9             0.620         0.19            3.90      0.170
# 17              8.1             0.560         0.28            1.70      0.368
# 18              7.4             0.590         0.08            4.40      0.086
# 19              7.9             0.320         0.51            1.80      0.341
# 20              8.9             0.220         0.48            1.80      0.077
# 21              7.6             0.390         0.31            2.30      0.082
# 22              7.9             0.430         0.21            1.60      0.106
# 23              8.5             0.490         0.11            2.30      0.084
# 24              6.9             0.400         0.14            2.40      0.085
# 25              6.3             0.390         0.16            1.40      0.080
# 26              7.6             0.410         0.24            1.80      0.080
# 27              7.9             0.430         0.21            1.60      0.106
# 28              7.1             0.710         0.00            1.90      0.080
# 29              7.8             0.645         0.00            2.00      0.082
# 30              6.7             0.675         0.07            2.40      0.089
# 32              8.3             0.655         0.12            2.30      0.083
# 33              6.9             0.605         0.12           10.70      0.073
# ...             ...               ...          ...             ...        ...
# 6409            5.4             0.375         0.40            3.30      0.054
# 6412            5.8             0.360         0.50            1.00      0.127
# 6419            5.8             0.360         0.50            1.00      0.127
# 6423            6.4             0.230         0.35           10.30      0.042
# 6427            6.4             0.230         0.35           10.30      0.042
# 6430            5.8             0.380         0.26            1.10      0.058
# 6435            6.7             0.500         0.36           11.50      0.096
# 6444            6.6             0.380         0.29            2.40      0.136
# 6448            6.4             0.330         0.44            8.90      0.055
# 6450            6.4             0.330         0.44            8.90      0.055
# 6454            7.1             0.230         0.39           13.70      0.058
# 6455            7.1             0.230         0.39           13.70      0.058
# 6457            6.4             0.350         0.51            7.80      0.055
# 6463            6.0             0.410         0.23            1.10      0.066
# 23     9.400000        5    red  Moderately High
# 24     9.700000        6    red              Low
# 25     9.300000        5    red              Low
# 26     9.500000        5    red           Medium
# 27     9.500000        5    red  Moderately High
# 28     9.400000        5    red              Low
# 29     9.800000        6    red              Low
# 30    10.100000        5    red              Low
# 32     9.800000        5    red  Moderately High
# 33     9.400000        6    red              Low
# ...         ...      ...    ...              ...
# 6409   9.100000        5  white              Low
# 6412   9.700000        5  white             High
# 6419   9.700000        5  white             High
# 6423   9.200000        5  white           Medium
# 6427   9.200000        5  white           Medium
# 6430   9.700000        6  white           Medium
# 6435   9.600000        5  white             High
# 6444   9.500000        5  white  Moderately High
# 6448   9.600000        5  white             High
# 6450   9.600000        5  white             High
# 6454   9.000000        6  white             High
# 6455   9.000000        6  white             High
# 6457   9.600000        5  white  Moderately High
# 6463   9.633333        5  white           Medium
# 6468   9.800000        6  white  Moderately High
# 6471   9.700000        5  white  Moderately High
# 6473  10.000000        6  white              Low
# 6474   9.700000        6  white  Moderately High
# 6476   8.800000        5  white           Medium
# 6477   9.500000        4  white           Medium
# 6478   9.533333        6  white  Moderately High
# 6479   9.533333        6  white  Moderately High
# 6480   9.400000        6  white             High
# 6483   9.600000        5  white  Moderately High
# 6484   9.550000        6  white  Moderately High
# 6487   9.200000        5  white             High
# 6488   9.400000        6  white             High
# 6491   9.700000        5  white           Medium
# 6493   9.600000        5  white  Moderately High
# 6494   9.400000        6  white             High
#
# [3177 rows x 14 columns]

# %%
# 选择酒精含量大于等于中位数的样本
high_alcohol =df.query('alcohol >= 10.30')

# 确保这些查询中的每个样本只出现一次
num_samples = df.shape[0]
num_samples == low_alcohol['quality'].count() + high_alcohol['quality'].count() # 应为真
# Out:
# True

# %%
# 获取低酒精含量组和高酒精含量组的平均质量评分
high_alcohol['quality'].mean()
# Out:
# 6.146084337349397

# %%
low_alcohol['quality'].mean()
# Out:
# 5.475920679886686

# %% [markdown]
# ### 口感较甜的酒是否评分较高？

# %%
# 获取残留糖分的中位数
# 3.000000
df['residual sugar'].describe()
# Out:
# count    6497.000000
# mean        5.443235
# std         4.757804
# min         0.600000
# 25%         1.800000
# 50%         3.000000
# 75%         8.100000
# max        65.800000
# Name: residual sugar, dtype: float64

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'color', 'acidity_levels'],
#       dtype='object')

# %%
df.rename(columns={'residual sugar':'residual_sugar'},inplace=True)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color   acidity_levels
# 0      9.4        5   red              Low
# 1      9.8        5   red  Moderately High
# 2      9.8        5   red           Medium
# 3      9.8        6   red  Moderately High
# 4      9.4        5   red              Low

# %% [markdown]
# * 注意此处存在的问题是：对于列名中包含 **空格** 的会导致query查询失败，所以需要将空格转成_

# %%
# 选择残留糖分小于中位数的样本
low_sugar =df.query('residual_sugar < 3')

# %%
# 选择残留糖分大于等于中位数的样本
high_sugar =df.query('residual_sugar >= 3')

# 确保这些查询中的每个样本只出现一次
num_samples == low_sugar['quality'].count() + high_sugar['quality'].count() # 应为真
# Out:
# True

# %%
# 获取低糖分组和高糖分组的平均质量评分
low_sugar['quality'].mean()
# Out:
# 5.808800743724822

# %%
high_sugar['quality'].mean()
# Out:
# 5.82782874617737

# %% [markdown]
# 参考网址：https://github.com/evaseemefly/DAND-QA/blob/master/Intro-DataAnalysis/L2-CaseStudy1/conclusions_query-zh.ipynb
