# %% [markdown]
# ## 本示例用来尝试根据指定的时间范围获取该时间范围及指定海洋站对应的路径

# %%
import os

path=r'E:\01开发\04数据分析相关\learn_sourcecode_DataAnalysis'
for root, dirs, files in os.walk(path): 
    print("-----------")
    print("root:%s"%root)
    print("dirs:%s"%dirs)
    print("files:%s"%files)
# Out:
# -----------
# root:E:\01开发\04数据分析相关\learn_sourcecode_DataAnalysis
# dirs:['.git', 'codes_bymyself', 'lect01_codes', 'lect02_codes', 'lect03_codes', 'lect04_codes']
# files:['.DS_Store', 'kernel-876dea59-65b4-45c9-ac6a-8a9b762cac84.json']
# -----------
# root:E:\01开发\04数据分析相关\learn_sourcecode_DataAnalysis\.git
# dirs:['hooks', 'info', 'logs', 'objects', 'refs']
# files:['config', 'description', 'HEAD', 'index', 'packed-refs']
# -----------
# root:E:\01开发\04数据分析相关\learn_sourcecode_DataAnalysis\.git\hooks
# dirs:[]
# files:['applypatch-msg.sample', 'commit-msg.sample', 'post-update.sample', 'pre-applypatch.sample', 'pre-commit.sample', 'pre-push.sample', 'pre-rebase.sample', 'prepare-commit-msg.sample', 'update.sample']
# -----------
# root:E:\01开发\04数据分析相关\learn_sourcecode_DataAnalysis\.git\info
# dirs:[]
# files:['exclude']
# -----------
# root:E:\01开发\04数据分析相关\learn_sourcecode_DataAnalysis\.git\logs
# dirs:['refs']
# files:['HEAD']
# -----------
# ...
